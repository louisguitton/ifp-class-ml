# %% [markdown]
# Link toward the documentation: http://pvlib-python-dacoex.readthedocs.io/en/pvsystem_tutport/modules.html

# %%
from pvlib import pvsystem
sandia_modules = pvsystem.retrieve_sam('sandiamod')

# %%
sandia_modules
# Out:
#                                          Advent_Solar_AS160___2006_  \
# Vintage                                                        2006
# Area                                                          1.312
# Material                                                      mc-Si
# Cells_in_Series                                                  72
# Parallel_Strings                                                  1
# Isco                                                          5.564
# Voco                                                         42.832
# Impo                                                          5.028
# Vmpo                                                          32.41
# Aisc                                                       0.000537
# Aimp                                                      -0.000491
# C0                                                           1.0233
# C1                                                          -0.0233
# ...
